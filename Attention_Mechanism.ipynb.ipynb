# %% [markdown]
# <a href="https://colab.research.google.com/github/rdemarqui/studies/blob/master/Attention_Mechanism.ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Attention

# %% [markdown]
# ## Understanding and Coding the Self-Attention Mechanism of Large Language Models From Scratch

# %% [markdown]
# Source: https://sebastianraschka.com/blog/2023/self-attention-from-scratch.html

# %% [markdown]
# ### Self-Attention

# %% [markdown]
# The concept of “attention” in deep learning has its roots in the effort to improve Recurrent Neural Networks (RNNs) for handling longer sequences or sentences. For instance, consider translating a sentence from one language to another. Translating a sentence word-by-word does not work effectively.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To overcome this issue, attention mechanisms were introduced to give access to all sequence elements at each time step. The key is to be selective and determine which words are most important in a specific context. In 2017, the transformer architecture introduced a standalone self-attention mechanism, eliminating the need for RNNs altogether.

# %% [markdown]
# ## Resources
# * https://sebastianraschka.com/blog/2023/self-attention-from-scratch.html
# * https://www.analyticsvidhya.com/blog/2023/06/learn-attention-models-from-scratch/
# * https://towardsdatascience.com/illustrated-self-attention-2d627e33b20a
# * https://benjaminwarner.dev/2023/07/01/attention-mechanism
# * https://machinelearningmastery.com/building-transformer-models-with-attention-crash-course-build-a-neural-machine-translator-in-12-days/
# * https://towardsdatascience.com/attention-and-its-different-forms-7fc3674d14dc
# * https://arxiv.org/abs/1706.03762
